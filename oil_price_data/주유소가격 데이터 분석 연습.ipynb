# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 데이터 불러오기
# - 2019년 주유소들의 일자별 가격 데이터

# %%
# 상반기, 하반기 주유소 가격 데이터 조회
first = pd.read_csv('data/2019년 상반기 주유소 판매가격.csv')
last = pd.read_csv('data/2019년 하반기 주유소 판매가격.csv')
first
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
last
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
# 상반기, 하반기 DataFrame 합치기
oil = pd.concat([first, last], ignore_index = True)
oil
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유
# ...

# %%
# DataFrame 기본 정보 조회
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 15.3+ MB

# %%
# 상표 컬럼의 고유값 조회
oil.columns
# Out:
# Index(['번호', '지역', '상호', '주소', '기간', '상표', '셀프여부', '고급휘발유', '휘발유', '경유',
#        '실내등유'],
#       dtype='object')

# %%
# 지역 컬럼의 고유값 조회
oil['지역'].values
# Out:
# array(['서울 강남구', '서울 강남구', '서울 강남구', ..., '서울 중랑구', '서울 중랑구', '서울 중랑구'],
#       dtype=object)

# %%
oil.describe()
# Out:
#                  기간          고급휘발유            휘발유             경유  \
# count  1.817140e+05  181714.000000  181714.000000  181714.000000
# mean   2.019067e+07     763.284139    1567.148161    1435.564816
# std    3.453131e+02     937.368150     182.942737     171.892815
# min    2.019010e+07       0.000000       0.000000       0.000000
# 25%    2.019040e+07       0.000000    1459.000000    1333.000000
# 50%    2.019070e+07       0.000000    1529.000000    1389.000000
# 75%    2.019093e+07    1768.000000    1599.000000    1478.000000
# max    2.019123e+07    2699.000000    2356.000000    2196.000000
#
#                 실내등유
# count  181714.000000
# mean      454.800412
# std       572.002790
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%      1100.000000
# max      1640.000000

# %%
oil.describe(include = 'object')
# Out:
#               번호      지역      상호              주소      상표    셀프여부
# count     181714  181714  181714          181714  181714  181714
# unique       512      25     507             512       8       2
# top     A0010031  서울 강남구   신성주유소  서울 강서구 양천로 176   SK에너지      일반
# freq         365   14597    1095             365   71062  108492

# %% [markdown]
# > ### str accessor
# > - `Series.str.String메소드()`
# > - 문자열 타입 Series에 String 메소드들을 사용하여 일괄처리 할 수 있도록 한다.
# > - str accessor 메소드 : https://pandas.pydata.org/pandas-docs/stable/reference/series.html#api-series-str
#
# > ### datetime으로 변환
# > - `pd.to_datetime(변환할 Series)`
# > - x 또는 y 축이 날짜 일 경우 datetime 타입으로 처리하는 것이 좋다.
# > - datetime을 변환하면 날짜만의 기능을 다룰 수 있다.
# >     - dt accessor를 이용해 datetime의 속성값들을(년, 월, 일 등) 추출할 수 있다.
# >     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html

# %%
# 지역 컬럼의 값을 이용하여 "구" 컬럼 생성 (지역에서 구만 추출)
oil['구'] = oil['지역'].str.lstrip('서울 ')
oil
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
# ...

# %%
oil['구'] = oil['지역'].str.split(' ').str[1]

# %%
# 기간 컬럼을 datetime 타입으로 변경
oil['기간'] = pd.to_datetime(oil['기간'], format = "%Y%m%d")
oil
# Out:
#               번호      지역             상호              주소         기간     상표  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지
# ...          ...     ...            ...             ...        ...    ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유    구
# ...

# %%
# read_csv로 읽을 때 변환
# parse_date = [datetime 타입으로 읽을 컬럼, ...]
# date_parser = 변환함수
from datetime import datetime
def parser(x):
    # strftime(): datetime -> str (to_char())
    # strptime(): str -> datetime (to_date())
    # x: 컬럼의 원소들
    return datetime.strptime(x, '%Y%m%d')
first2 = pd.read_csv('data/2019년 상반기 주유소 판매가격.csv', 
                     parse_dates = ['기간'],
                     date_parser = parser)
first2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90590 entries, 0 to 90589
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      90590 non-null  object
#  1   지역      90590 non-null  object
#  2   상호      90590 non-null  object
#  3   주소      90590 non-null  object
#  4   기간      90590 non-null  datetime64[ns]
#  5   상표      90590 non-null  object
#  6   셀프여부    90590 non-null  object
#  7   고급휘발유   90590 non-null  int64
#  8   휘발유     90590 non-null  int64
#  9   경유      90590 non-null  int64
#  10  실내등유    90590 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 7.6+ MB

# %%
first3 = pd.read_csv('data/2019년 상반기 주유소 판매가격.csv', 
                     parse_dates = ['기간'],
                     date_parser = lambda x: datetime.strptime(x, '%Y%m%d'))
first3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90590 entries, 0 to 90589
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      90590 non-null  object
#  1   지역      90590 non-null  object
#  2   상호      90590 non-null  object
#  3   주소      90590 non-null  object
#  4   기간      90590 non-null  datetime64[ns]
#  5   상표      90590 non-null  object
#  6   셀프여부    90590 non-null  object
#  7   고급휘발유   90590 non-null  int64
#  8   휘발유     90590 non-null  int64
#  9   경유      90590 non-null  int64
#  10  실내등유    90590 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 7.6+ MB

# %%
# 기간 컬럼을 이용해 "월", "일", "요일" 컬럼 생성
oil['월'] = oil['기간'].dt.month
oil['일'] = oil['기간'].dt.day
oil['요일'] = oil['기간'].dt.dayofweek
oil
# Out:
#               번호      지역             상호              주소         기간     상표  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지
# ...          ...     ...            ...             ...        ...    ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유    구   월   일  요일
# ...

# %%
# 요일을 문자열로 변환 (0-월, 6-일)
def change_day_str(x):
    if x == 0:
        return '월'
    elif x == 1:
        return '화'
    elif x == 2:
        return '수'
    elif x == 3:
        return '목'
    elif x == 4:
        return '금'
    elif x == 5:
        return '토'
    else:
        return '일'

# %%
oil['요일'] = oil['요일'].apply(change_day_str)
oil.head()
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유    구  월  일 요일
# 0   1673  1465  1365     0  강남구  1  1  화
# 1   1673  1465  1365     0  강남구  1  2  수
# 2   1673  1465  1365     0  강남구  1  3  목
# 3   1673  1465  1365     0  강남구  1  4  금
# 4   1673  1465  1365     0  강남구  1  5  토

# %%
# 휘발유 가격이 가장 비싼 5개 행 조회
oil.sort_values('휘발유', ascending = False)[:5]
# Out:
#               번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 177210  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 177216  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 177217  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 177211  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 177212  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#          휘발유    경유  실내등유   구   월   일  요일
# 177210  2356  2196     0  중구   9  24   1
# 177216  2356  2196     0  중구   9  30   0
# 177217  2356  2196     0  중구  10   1   1
# 177211  2356  2196     0  중구   9  25   2
# 177212  2356  2196     0  중구   9  26   3

# %%
# 휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
oil[oil['휘발유'] > 0].sort_values('휘발유')[:5]
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82998  A0000690  서울 은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동) 2019-01-26
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구  월   일  요일
# 13148  SK에너지   셀프   1788  1255  1155     0  강서구  2   7   3
# 82475  SK에너지   일반      0  1260  1160     0  은평구  1  31   3
# 82474  SK에너지   일반      0  1260  1160     0  은평구  1  30   2
# 82476  SK에너지   일반      0  1260  1160     0  은평구  2   1   4
# 82998  GS칼텍스   셀프      0  1265  1165     0  은평구  1  26   5

# %%
# 고급휘발유 가격이 가장 비싼 5개 행 조회
oil.sort_values('고급휘발유', ascending = False)[:5]
# Out:
#               번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 177217  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 177212  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
# 177213  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-27  SK에너지   일반   2699
# 177214  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-28  SK에너지   일반   2699
# 177215  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-29  SK에너지   일반   2699
#
#          휘발유    경유  실내등유   구   월   일  요일
# 177217  2356  2196     0  중구  10   1   1
# 177212  2356  2196     0  중구   9  26   3
# 177213  2356  2196     0  중구   9  27   4
# 177214  2356  2196     0  중구   9  28   5
# 177215  2356  2196     0  중구   9  29   6

# %%
# 고급휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
oil[oil['고급휘발유'] > 0].sort_values('고급휘발유')[:5]
# Out:
#              번호      지역       상호                       주소         기간     상표  \
# 17460  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-15  S-OIL
# 17459  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-14  S-OIL
# 17458  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-13  S-OIL
# 17457  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-12  S-OIL
# 17456  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-11  S-OIL
#
#       셀프여부  고급휘발유   휘발유    경유  실내등유    구  월   일  요일
# 17460   셀프   1397  1275  1175     0  강서구  1  15   1
# 17459   셀프   1397  1275  1175     0  강서구  1  14   0
# 17458   셀프   1397  1275  1175     0  강서구  1  13   6
# 17457   셀프   1397  1275  1175     0  강서구  1  12   5
# 17456   셀프   1397  1275  1175     0  강서구  1  11   4

# %%
# 경유 가격이 가장 비싼 5개 행 조회
oil.sort_values('경유', ascending = False)[:5]
# Out:
#               번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 177211  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 177212  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
# 177217  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 177216  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 177215  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-29  SK에너지   일반   2699
#
#          휘발유    경유  실내등유   구   월   일  요일
# 177211  2356  2196     0  중구   9  25   2
# 177212  2356  2196     0  중구   9  26   3
# 177217  2356  2196     0  중구  10   1   1
# 177216  2356  2196     0  중구   9  30   0
# 177215  2356  2196     0  중구   9  29   6

# %%
# 경유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
oil[oil['경유'] > 0].sort_values('경유')[:5]
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 50707  A0011826  서울 서초구             만남의광장주유소  서울 서초구 양재대로12길 73-71 2019-01-13
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
#
#            상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구  월   일  요일
# 13148   SK에너지   셀프   1788  1255  1155     0  강서구  2   7   3
# 50707  알뜰(ex)   셀프      0  1297  1157     0   초구  1  13   6
# 82476   SK에너지   일반      0  1260  1160     0  은평구  2   1   4
# 82475   SK에너지   일반      0  1260  1160     0  은평구  1  31   3
# 82474   SK에너지   일반      0  1260  1160     0  은평구  1  30   2

# %%
# 상표별 휘발유 평균가격 조회
oil[oil['휘발유'] != 0].groupby('상표')['휘발유'].mean()
# Out:
# 상표
# GS칼텍스     1564.313469
# NH-OIL    1449.088889
# S-OIL     1532.472987
# SK에너지     1612.782625
# 알뜰(ex)    1431.347945
# 알뜰주유소     1447.875902
# 자가상표      1492.085540
# 현대오일뱅크    1515.670352
# Name: 휘발유, dtype: float64

# %%
# 상표별 휘발유 평균가격 시각화
plt.figure(figsize = (10, 6))
oil[oil['휘발유'] != 0].groupby('상표')['휘발유'].mean().plot.bar(rot = 30, label = '휘발유 가격')
for idx, val in enumerate(oil[oil['휘발유'] != 0].groupby('상표')['휘발유'].mean()):
    plt.text(idx - 0.4, val + 20, np.round(val, 2), fontsize = 8)
    
plt.axhline(1500, color = 'r', linestyle = '--', label = '1500원 기준선')  
# axhline: 가로로 선 긋기 / axvline: 세로로 선 긋기

plt.legend(bbox_to_anchor = (1, 1), loc = 'upper left')
plt.show()

# %%
# 셀프주유소와 일반주유소 개수 확인
oil['셀프여부'].value_counts()
# Out:
# 일반    108492
# 셀프     73222
# Name: 셀프여부, dtype: int64

# %%
# 셀프주유소와 일반주유소 개수 시각화
oil['셀프여부'].value_counts().plot.bar(rot = 0)
for idx, self in enumerate(oil['셀프여부'].value_counts()):
    plt.text(idx - 0.15, self + 1000, self, fontsize = 15)

# %%
# 셀프 여부에 따른 휘발유 평균 가격 비교
oil.groupby('셀프여부')['휘발유'].mean()
# Out:
# 셀프여부
# 셀프    1490.160266
# 일반    1619.107824
# Name: 휘발유, dtype: float64

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교
oil.groupby(['상표', '셀프여부'])['휘발유'].mean()
# Out:
# 상표      셀프여부
# GS칼텍스   셀프      1481.410074
#         일반      1610.060123
# NH-OIL  일반      1449.088889
# S-OIL   셀프      1481.437428
#         일반      1579.451162
# SK에너지   셀프      1504.853863
#         일반      1690.377765
# 알뜰(ex)  셀프      1431.347945
# 알뜰주유소   셀프      1434.726027
#         일반      1455.372511
# 자가상표    셀프      1494.409449
#         일반      1491.740351
# 현대오일뱅크  셀프      1483.546767
#         일반      1534.254225
# Name: 휘발유, dtype: float64

# %%
셀프여부_휘발유_mean = oil[oil['휘발유'] != 0].pivot_table(values = '휘발유',
                                                      index = '상표', 
                                                      columns = '셀프여부',
                                                      aggfunc = 'mean')
셀프여부_휘발유_mean
# Out:
# 셀프여부             셀프           일반
# 상표
# GS칼텍스   1481.410074  1610.516144
# NH-OIL          NaN  1449.088889
# S-OIL   1481.437428  1579.789061
# SK에너지   1505.054771  1691.365496
# 알뜰(ex)  1431.347945          NaN
# 알뜰주유소   1434.726027  1455.372511
# 자가상표    1494.409449  1491.740351
# 현대오일뱅크  1483.686804  1534.510147

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교 시각화
셀프여부_휘발유_mean.plot.bar(figsize = (10, 6))
plt.legend(bbox_to_anchor = (1, 1), loc = 'upper left')
plt.show()

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격에 대한 분포 확인 - boxplot으로 시각화
sns.boxplot(y = '상표', x = '휘발유', hue = '셀프여부', data = oil)
plt.show()

# %%
# 상표별 휘발유 가격의 분포를 boxplot으로 시각화
sns.boxplot(y = '상표', x = '휘발유', data = oil)
plt.show()

# %%
# 상표별 휘발유 가격의 분포를 셀프여부로 나눠 boxplot으로 시각화
sns.boxplot(y = '휘발유', x = '셀프여부', hue = '상표', data = oil)
plt.legend(bbox_to_anchor = (1, 1), loc = 'upper left')
plt.show()

# %%
# 구별 휘발유 가격의 평균
oil.groupby('구')['휘발유'].mean().round(2)
# Out:
# 구
# 강남구     1713.09
# 강동구     1576.69
# 강북구     1453.52
# 강서구     1488.82
# 관악구     1518.13
# 광진구     1490.60
# 구로구     1525.41
# 금천구     1477.12
# 노원구     1531.22
# 도봉구     1494.17
# 동대문구    1506.83
# 동작구     1512.47
# 마포구     1689.76
# 서대문구    1528.94
# 서초구     1577.13
# 성동구     1583.66
# 성북구     1507.95
# 송파구     1518.96
# 양천구     1512.89
# 영등포구    1568.28
# 용산구     1882.05
# 은평구     1481.96
# 종로구     1838.55
# 중구      1976.95
# 중랑구     1469.01
# Name: 휘발유, dtype: float64

# %%
# 구별 휘발유 가격의 평균 시각화
oil.groupby('구')['휘발유'].mean().round(2).plot.bar(figsize = (10, 7), rot = 40, label = '휘발유 가격')
# 평균가격을 기준선으로
plt.axhline(oil['휘발유'].mean(), color = 'r', label = '전체평균')
plt.legend()
plt.show()

# %%
# 중구(평균이 가장높음)의 상표별 휘발유 평균가격
oil[oil['구'] == '중구'].groupby('상표')['휘발유'].mean()
# Out:
# 상표
# GS칼텍스     2091.866438
# S-OIL     1783.369863
# SK에너지     2060.617512
# 알뜰주유소     1601.552743
# 자가상표      1418.859375
# 현대오일뱅크    1711.669903
# Name: 휘발유, dtype: float64

# %%
# 월 평균 휘발유 가격의 평균
oil.groupby('월')['휘발유'].mean().mean()
# Out:
# 1566.9283374071913

# %%
# 월별 휘발유 가격 변화 추세 시각화
oil.groupby('월')['휘발유'].mean().plot.line()

plt.xticks(range(1, 13), labels = [f'{i}월' for i in range(1, 13)])  # ticks위치, label(생략-tick의 위치가 label)
plt.show()

# %%
# 각 구의 월별 평균 휘발유 가격 
oil.groupby(['구', '월'])['휘발유'].mean()
# Out:
# 구    월
# 강남구  1     1619.865825
#      2     1600.945536
#      3     1616.143548
#      4     1666.350000
#      5     1739.208232
#               ...
# 초구   8     1599.360070
#      9     1644.167568
#      10    1650.737646
#      11    1640.041121
#      12    1643.736559
# Name: 휘발유, Length: 300, dtype: float64

# %%
oil.pivot_table(values = '휘발유', index = '월', columns = '구', aggfunc = 'mean')
# Out:
# 구           강남구          강동구          강북구          강서구          관악구  \
# 월
# 1   1619.865825  1503.383302  1357.002488  1376.357474  1429.822262
# 2   1600.945536  1478.109244  1345.565934  1370.397959  1405.984127
# 3   1616.143548  1468.138277  1342.990074  1392.716129  1403.370510
# 4   1666.350000  1526.341667  1414.246154  1447.910749  1456.301230
# 5   1739.208232  1605.267206  1500.025126  1543.218433  1548.151210
# 6   1744.065833  1608.388309  1491.889744  1522.746425  1564.633333
# 7   1734.204712  1588.002020  1469.147132  1502.133396  1543.155242
# 8   1735.209040  1589.324597  1468.318408  1508.055028  1543.354839
# 9   1773.644167  1638.926931  1514.569231  1554.135693  1586.991649
# 10  1780.519355  1650.838710  1515.558313  1549.533207  1586.917339
# 11  1768.602500  1632.787500  1505.035897  1537.513725  1582.785417
# 12  1773.900082  1635.522177  1511.468983  1560.121673  1591.328629
#
# 구           광진구          구로구          금천구          노원구          도봉구  ...  \
# ...

# %%
# 각 구의 월별 평균가격의 변화추이 시각화
#oil.groupby(['구', '월'])['휘발유'].mean().plot.line()
oil.pivot_table(index = '월', columns = '구', values = '휘발유', aggfunc = 'mean').plot.line()
plt.legend(bbox_to_anchor = (1, 1), loc = 'upper left', ncol = 2)

# %%
# 가장 휘발유가격이 비싼 주유소 상위 5 
oil.sort_values('휘발유', ascending = False)[:5]
# Out:
#               번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 177210  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 177216  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 177217  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 177211  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 177212  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#          휘발유    경유  실내등유   구   월   일  요일
# 177210  2356  2196     0  중구   9  24   1
# 177216  2356  2196     0  중구   9  30   0
# 177217  2356  2196     0  중구  10   1   1
# 177211  2356  2196     0  중구   9  25   2
# 177212  2356  2196     0  중구   9  26   3

# %%
비싼주유소 = oil.groupby('상호')['휘발유'].mean().sort_values(ascending = False).head()
비싼주유소
# Out:
# 상호
# 서남주유소          2207.252055
# 장충주유소          2139.323288
# 뉴서울(강남)        2130.060274
# SC(주) 역전주유소    2125.778082
# 필동주유소          2098.095890
# Name: 휘발유, dtype: float64

# %%
# 가장 휘발유가격이 저렴한 주유소 상위 5 
oil[oil['휘발유'] > 0].sort_values('휘발유', ascending = True)[:5]
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82998  A0000690  서울 은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동) 2019-01-26
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구  월   일  요일
# 13148  SK에너지   셀프   1788  1255  1155     0  강서구  2   7   3
# 82475  SK에너지   일반      0  1260  1160     0  은평구  1  31   3
# 82474  SK에너지   일반      0  1260  1160     0  은평구  1  30   2
# 82476  SK에너지   일반      0  1260  1160     0  은평구  2   1   4
# 82998  GS칼텍스   셀프      0  1265  1165     0  은평구  1  26   5

# %%
싼주유소 = oil.groupby('상호')['휘발유'].mean().sort_values(ascending = True).head()
싼주유소
# Out:
# 상호
# (주)창원현대주유소           1362.553719
# 엘스카운티(주)천동주유소        1397.306452
# SK네트웍스(주) 서울셀프주유소    1407.505051
# KH에너지(주)직영 수명산주유소    1416.021739
# 이케이에너지㈜ 강산주유소        1416.290909
# Name: 휘발유, dtype: float64

# %%
# 휘발유 비싼 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거-drop_duplicates())
oil.sort_values('휘발유', ascending = False)[['상호', '지역', '주소']].drop_duplicates().head()
# Out:
#                  상호      지역                      주소
# 177210        서남주유소   서울 중구            서울 중구 통일로 30
# 176953  SC(주) 역전주유소   서울 중구            서울 중구 퇴계로 15
# 178316        필동주유소   서울 중구   서울 중구  퇴계로 196 (필동2가)
# 177934        장충주유소   서울 중구  서울 중구 장충단로 202 (장충동1가)
# 93593       뉴서울(강남)  서울 강남구    서울 강남구 언주로 716 (논현동)

# %%
oil.loc[oil['상호'].isin(비싼주유소.index), ['상호', '지역', '주소']].drop_duplicates()
# Out:
#                 상호      지역                      주소
# 2896       뉴서울(강남)  서울 강남구    서울 강남구 언주로 716 (논현동)
# 85869  SC(주) 역전주유소   서울 중구            서울 중구 퇴계로 15
# 86231        서남주유소   서울 중구            서울 중구 통일로 30
# 86955        장충주유소   서울 중구  서울 중구 장충단로 202 (장충동1가)
# 87317        필동주유소   서울 중구   서울 중구  퇴계로 196 (필동2가)

# %%
# 휘발유 저렴한 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거)
oil[oil['휘발유'] != 0].sort_values('휘발유', ascending = True)[['상호', '지역', '주소', '휘발유']].drop_duplicates().head()
# Out:
#                         상호      지역                     주소   휘발유
# 13148  KH에너지(주)직영 KH외발산주유소  서울 강서구         서울 강서구 방화대로 30  1255
# 82475                삼융주유소  서울 은평구   서울 은평구 수색로 299 (수색동)  1260
# 82998    지에스칼텍스(주)수색뉴타운주유소  서울 은평구   서울 은평구 수색로 350 (수색동)  1265
# 14045            강서오곡셀프주유소  서울 강서구   서울 강서구 벌말로 254 (오곡동)  1267
# 16015               스카이주유소  서울 강서구  서울 강서구 개화동로 457 (방화동)  1273

# %%
oil.loc[oil['상호'].isin(싼주유소.index), ['상호', '지역', '주소', '휘발유']].drop_duplicates()
# Out:
#                        상호      지역                       주소   휘발유
# 9436        엘스카운티(주)천동주유소  서울 강동구    서울 강동구 천호대로 987 (천호동)  1498
# 9442        엘스카운티(주)천동주유소  서울 강동구    서울 강동구 천호대로 987 (천호동)  1465
# 9495        엘스카운티(주)천동주유소  서울 강동구    서울 강동구 천호대로 987 (천호동)     0
# 13472   KH에너지(주)직영 수명산주유소  서울 강서구  서울 강서구 남부순환로 195 (내발산동)  1398
# 13475   KH에너지(주)직영 수명산주유소  서울 강서구  서울 강서구 남부순환로 195 (내발산동)  1352
# ...                   ...     ...                      ...   ...
# 151492      이케이에너지㈜ 강산주유소  서울 성북구    서울 성북구 보문로 27 (보문동7가)  1482
# 151523      이케이에너지㈜ 강산주유소  서울 성북구    서울 성북구 보문로 27 (보문동7가)  1475
# 151533      이케이에너지㈜ 강산주유소  서울 성북구    서울 성북구 보문로 27 (보문동7가)  1492
# 151546      이케이에너지㈜ 강산주유소  서울 성북구    서울 성북구 보문로 27 (보문동7가)  1502
# 151556      이케이에너지㈜ 강산주유소  서울 성북구    서울 성북구 보문로 27 (보문동7가)  1512
#
# [69 rows x 4 columns]

# %%
# -> 상호별로 날짜마다 가격이 다르기 때문에 상호로 그룹을 묶고 정렬하는 방식이 더 적절하다.
